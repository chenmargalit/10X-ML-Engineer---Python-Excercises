# %% [markdown]
# Lambda function

# %%
sum_lambda_func = lambda a,b: a+b

# %%
sum_lambda_func(1,2)
# Out:
# 3

# %%
def sum_func(a, b):
    return a+b

# %%
unordered_list = [{'a': 1}, ('c': 3), ('a': -3)]
# Out:
#   Cell In[17], line 1
#     unordered_list = {('a': 1), ('c': 3), ('a': -3)}
#                           ^
# SyntaxError: invalid syntax

# %%
ice_cream_flavors = [
    {"name": "Choclate", "taste": 85},
    {"name": "Vanilla", "taste": 72},
    {"name": "Gum", "taste": 100},
]

# %%
sorted(ice_cream_flavors, key=lambda x: x['taste'], reverse=True)
# Out:
# [{'name': 'Gum', 'taste': 100},
#  {'name': 'Choclate', 'taste': 85},
#  {'name': 'Vanilla', 'taste': 72}]

# %%
sorted(['a', 'c', 'm'])
# Out:
# ['a', 'c', 'm']

# %%
# %%time

import random

nums = []
num_of_numbers = 100_000_00
for num in range(num_of_numbers):
    nums.append(random.randint(0, num_of_numbers))
# Out:
# CPU times: user 2.98 s, sys: 63.8 ms, total: 3.05 s
# Wall time: 3.05 s

# %%
# %time nums1 = [random.randint(1, 10_000) for x in range(10_000)]
# Out:
# CPU times: user 12.3 ms, sys: 2.69 ms, total: 15 ms
# Wall time: 14.1 ms

# %%
len(nums1)
# Out:
# 10000

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less_than_pivot = [x for x in arr[1:] if x <= pivot]
        greater_than_pivot = [x for x in arr[1:] if x > pivot]

        return quick_sort(less_than_pivot) + [pivot] + quick_sort(greater_than_pivot)

# Example usage:
random_numbers = [random.randint(1, 1000) for _ in range(10000)]

print("Before sorting:")
print(random_numbers[:10])

random_numbers = quick_sort(random_numbers)

print("\nAfter sorting:")
print(random_numbers[:10])
# Out:
# Before sorting:
# [369, 576, 510, 407, 589, 378, 159, 596, 552, 715]
#
# After sorting:
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]

# %%
# %time quick_sort(nums)
# Out:
# CPU times: user 18.7 s, sys: 485 ms, total: 19.2 s
# Wall time: 19.2 s
# [0,
#  1,
#  3,
#  5,
#  6,
#  7,
#  7,
#  8,
#  9,
#  10,
#  13,
#  13,
#  17,
#  17,
#  18,
#  18,
#  18,
#  23,
#  23,
#  23,
#  25,
#  26,
#  26,
#  26,
#  27,
#  27,
#  33,
#  34,
#  35,
#  35,
#  36,
#  36,
#  38,
#  38,
#  39,
#  39,
#  39,
#  39,
#  40,
#  40,
#  41,
#  42,
#  42,
#  43,
#  43,
#  45,
#  45,
#  46,
#  46,
#  46,
#  46,
#  47,
#  48,
#  48,
#  48,
#  48,
#  49,
#  51,
#  51,
#  51,
#  54,
#  55,
#  56,
#  56,
#  57,
#  57,
#  57,
#  60,
#  61,
#  63,
#  66,
#  68,
#  68,
#  69,
#  71,
#  72,
#  72,
#  75,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  79,
#  79,
#  80,
#  81,
#  82,
#  86,
#  87,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  91,
#  91,
#  92,
#  92,
#  92,
#  95,
#  95,
#  96,
#  96,
#  96,
#  98,
#  99,
#  100,
#  100,
#  100,
#  100,
#  105,
#  106,
#  110,
#  110,
#  111,
#  111,
#  114,
#  116,
#  116,
#  117,
#  118,
#  118,
#  121,
#  123,
#  124,
#  127,
#  127,
# ...

# %%
# %time sorted(nums)
# Out:
# CPU times: user 1.61 s, sys: 55.5 ms, total: 1.67 s
# Wall time: 1.66 s
# [0,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  5,
#  6,
#  6,
#  6,
#  6,
#  7,
#  7,
#  8,
#  9,
#  9,
#  9,
#  9,
#  9,
#  10,
#  13,
#  14,
#  17,
#  17,
#  19,
#  20,
#  21,
#  21,
#  21,
#  23,
#  24,
#  25,
#  28,
#  28,
#  29,
#  30,
#  31,
#  34,
#  35,
#  36,
#  36,
#  39,
#  40,
#  41,
#  41,
#  41,
#  42,
#  42,
#  43,
#  43,
#  43,
#  44,
#  45,
#  45,
#  45,
#  45,
#  46,
#  47,
#  48,
#  48,
#  48,
#  49,
#  50,
#  51,
#  52,
#  52,
#  56,
#  57,
#  58,
#  58,
#  60,
#  60,
#  62,
#  64,
#  64,
#  65,
#  69,
#  71,
#  71,
#  71,
#  73,
#  73,
#  74,
#  77,
#  85,
#  85,
#  85,
#  86,
#  87,
#  88,
#  90,
#  91,
#  92,
#  92,
#  94,
#  94,
#  95,
#  101,
#  101,
#  102,
#  103,
#  104,
#  106,
#  106,
#  108,
#  109,
#  110,
#  112,
#  113,
#  114,
#  115,
#  121,
#  121,
#  121,
#  122,
#  122,
#  123,
#  123,
#  124,
#  125,
#  127,
#  128,
#  129,
#  129,
#  129,
#  132,
#  132,
#  132,
#  133,
# ...
