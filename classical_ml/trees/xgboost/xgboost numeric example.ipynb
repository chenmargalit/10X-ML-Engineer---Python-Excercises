# %%
import pandas as pd

# %% [markdown]
# # XGBoost Numeric Example

# %%
data = {
    'goals': [1, 2, 3, 4],
    'Wins': [10, 15, 25, 35]
}

data = pd.DataFrame(data)

# %%
data
# Out:
#    goals  Wins
# 0      1    10
# 1      2    15
# 2      3    25
# 3      4    35

# %% [markdown]
# ### Step 2: Initial Prediction
# The initial prediction is simply the mean of the target 'Wins'.

# %%
initial_prediction = data['Wins'].mean()
data['Initial Prediction'] = initial_prediction
data
# Out:
#    goals  Wins  Initial Prediction
# 0      1    10               21.25
# 1      2    15               21.25
# 2      3    25               21.25
# 3      4    35               21.25

# %% [markdown]
# ### Step 3: Calculate Residuals
# Residuals are the difference between the actual 'Wins' and the initial predictions.

# %%
data['Residuals'] = data['Wins'] - data['Initial Prediction']
data
# Out:
#    goals  Wins  Initial Prediction  Residuals
# 0      1    10               21.25     -11.25
# 1      2    15               21.25      -6.25
# 2      3    25               21.25       3.75
# 3      4    35               21.25      13.75

# %% [markdown]
# ### Step 4: Train a Tree to Predict Residuals
# For simplicity, we will assume the tree learns the following predicted residuals.

# %%
data['Predicted Residuals'] = [-9, -5, 4, 10]
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10

# %%
lr = 0.1

# %% [markdown]
# ### Step 5: Update Predictions
# Update the model's predictions by adding the predicted residuals to the initial predictions.

# %%
data['Updated Prediction'] = data['Initial Prediction'] + lr * data['Predicted Residuals']
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals  \
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10
#
#    Updated Prediction
# 0               20.35
# 1               20.75
# 2               21.65
# 3               22.25

# %% [markdown]
# ### Step 6: Calculate New Residuals
# Calculate the new residuals based on the updated predictions.

# %%
data['New Residuals'] = data['Wins'] - data['Updated Prediction']
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals  \
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10
#
#    Updated Prediction  New Residuals
# 0               20.35         -10.35
# 1               20.75          -5.75
# 2               21.65           3.35
# 3               22.25          12.75

# %%
data['Predicted Residuals2'] = [-10, -5.5, 3.2, 11]
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals  \
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10
#
#    Updated Prediction  New Residuals  Predicted Residuals2
# 0               20.35         -10.35                 -10.0
# 1               20.75          -5.75                  -5.5
# 2               21.65           3.35                   3.2
# 3               22.25          12.75                  11.0

# %%
data['Updated Prediction2'] = data['Updated Prediction'] + lr * data['Predicted Residuals2']
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals  \
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10
#
#    Updated Prediction  New Residuals  Predicted Residuals2  \
# 0               20.35         -10.35                 -10.0
# 1               20.75          -5.75                  -5.5
# 2               21.65           3.35                   3.2
# 3               22.25          12.75                  11.0
#
#    Updated Prediction2
# 0                19.35
# 1                20.20
# 2                21.97
# 3                23.35

# %%
data['Final Prediction'] = data['Updated Prediction2']

# %%
data
# Out:
#    goals  Wins  Initial Prediction  Residuals  Predicted Residuals  \
# 0      1    10               21.25     -11.25                   -9
# 1      2    15               21.25      -6.25                   -5
# 2      3    25               21.25       3.75                    4
# 3      4    35               21.25      13.75                   10
#
#    Updated Prediction  New Residuals  Predicted Residuals2  \
# 0               20.35         -10.35                 -10.0
# 1               20.75          -5.75                  -5.5
# 2               21.65           3.35                   3.2
# 3               22.25          12.75                  11.0
#
#    Updated Prediction2  Final Prediction
# 0                19.35             19.35
# 1                20.20             20.20
# 2                21.97             21.97
# 3                23.35             23.35
